# %%
# functions : cv2.imread(), cv2.imshow() , cv2.imwrite()

# %%
# To install
# !pip install opencv-python

# %%
import cv2

# %%
# Read the image
# Syntax
#imread()
# cv2.imread(/complete/path/to/image,flag)

# %%
First argument is complete path to the image along with the extension.

Second argument is an optional flag which could be any one of the following :

cv2.IMREAD_COLOR : Loads a color image. Any transparency of image will be neglected. It is the default flag.
cv2.IMREAD_GRAYSCALE : Loads image in grayscale mode
cv2.IMREAD_UNCHANGED : Loads image as such including alpha channel

# %% [markdown]
# * Returns numpy array, containing the pixel values.
# * For colored images, each pixel is represented as an array containing Red, Green and Blue channels.
#
# * Note that the default flag is cv2.IMREAD_COLOR.
# * Hence even if read a png image with transparency, the transparency channel is neglected.

# %%
img=cv2.imread('lion.jpg',0)

# %% [markdown]
# ![Screenshot%20from%202019-09-01%2001-34-09.png](attachment:Screenshot%20from%202019-09-01%2001-34-09.png)

# %%
# Note Instead of these three flags, you can simply pass integers 1, 0 or -1 respectively.

# %%
print(img)
# Out:
# [[[242 245 250]
#   [242 245 250]
#   [242 245 250]
#   ...
#   [241 245 250]
#   [241 245 250]
#   [241 245 250]]
#
#  [[242 245 250]
#   [242 245 250]
#   [242 245 250]
#   ...
#   [241 245 250]
#   [241 245 250]
#   [241 245 250]]
#
#  [[242 245 250]
#   [242 245 250]
#   [242 245 250]
#   ...
#   [241 245 250]
#   [241 245 250]
#   [241 245 250]]
#
#  ...
#
#  [[ 77 132 177]
#   [ 78 133 178]
#   [ 77 132 177]
#   ...
#   [ 38  80 133]
#   [ 39  83 137]
#   [ 29  73 127]]
#
#  [[ 79 134 179]
#   [ 79 134 179]
#   [ 78 133 178]
#   ...
#   [ 33  75 128]
#   [ 37  81 135]
#   [ 27  71 125]]
#
#  [[ 79 134 179]
#   [ 80 135 180]
#   [ 79 134 179]
#   ...
#   [ 24  66 119]
#   [ 32  76 130]
#   [ 24  68 122]]]

# %% [markdown]
# #### Syntax – cv2.imshow() Methog

# %% [markdown]
# # Show image / display image
# cv2.imshow(window_name, image)
# imshow()

# %%
cv2.imshow('image',img)
cv2.waitKey(200)
cv2.destroyAllWindows()

# %% [markdown]
# * First argument is name of the window that is displayed when image is shown in.
#
# * Second argument is the image to be shown in the window.

# %% [raw]
# cv2.imwrite('copy' , img)
